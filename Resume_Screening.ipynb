# %% [markdown]
# # Resume Screening Using Natural Language Processing
#
# ## Project Category
#
# Natural Language Processing (NLP) / HR Analytics / Machine Learning
#
# ---
#
# ## Objective
#
# The objective of this project is to automate resume screening using Natural Language Processing techniques.
#
# The project aims to classify resumes into different job categories based on the skills, qualifications, and experiences described in the resume text.
#
# This can help recruiters and HR professionals quickly identify suitable candidates and improve the efficiency of the recruitment process.
#
# ---
#
# ## Dataset Information
#
# This project uses a resume dataset containing resume texts and their corresponding job categories.
#
# Target Variable:
#
# - Category
#
# Input Variable:
#
# - Resume
#
# ### Dataset Link
#
# https://www.kaggle.com/datasets/snehaanbhawal/resume-dataset?
#
# ---
#
# ## Techniques Used
#
# - Data Cleaning
# - Text Preprocessing
# - Natural Language Processing (NLP)
# - TF-IDF Vectorization
# - Text Classification
# - Resume Category Prediction
# - HR Analytics
#
# ---
#
# ## Libraries Used
#
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - NLTK
# - Scikit-learn
#
# ---
#
# ## Evaluation Metrics
#
# - Accuracy
# - Precision
# - Recall
# - F1 Score
# - Confusion Matrix
#
# ---
#
# ## Models Used
#
# - Logistic Regression
# - Naive Bayes
# - Random Forest
#
# ---
#
# ## Project Workflow
#
# 1. Data Loading
# 2. Data Cleaning
# 3. Exploratory Data Analysis
# 4. Text Preprocessing
# 5. TF-IDF Vectorization
# 6. Label Encoding
# 7. Train-Test Split
# 8. Model Training
# 9. Model Evaluation
# 10. Resume Category Prediction
# 11. Confusion Matrix
# 12. Conclusion

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d0b0748-ac08-4ffa-86c6-18664eedf531" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d0b0748-ac08-4ffa-86c6-18664eedf531">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b05e67d5-acfb-4029-83a7-488a19767170" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b05e67d5-acfb-4029-83a7-488a19767170">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

os.listdir()
# Out:
# ['.config',
#  '18368613.pdf',
#  '92200491.pdf',
#  '13637605.pdf',
#  '34131484.pdf',
#  '10464113.pdf',
#  '26530696.pdf',
#  '69155584.pdf',
#  '37360517.pdf',
#  '90682785.pdf',
#  '55477468.pdf',
#  '12696104.pdf',
#  '28139742.pdf',
#  '29399491.pdf',
#  '15620421.pdf',
#  '29184740.pdf',
#  '17378327.pdf',
#  '19582792.pdf',
#  '19147494.pdf',
#  '27607632.pdf',
#  '20552814.pdf',
#  '25810233.pdf',
#  '36074301.pdf',
#  '10603337.pdf',
#  '65456466.pdf',
#  '25315791.pdf',
#  '58428843.pdf',
#  '18171955.pdf',
#  '54101961.pdf',
#  '25839123.pdf',
#  '16121015.pdf',
#  '85918100.pdf',
#  '18062906.pdf',
#  '51349448.pdf',
#  '42304307.pdf',
#  '34303500.pdf',
#  '23929500.pdf',
#  '98108571.pdf',
#  '37735467.pdf',
#  '36621169.pdf',
#  '38087844.pdf',
#  '24610685.pdf',
#  '22047665.pdf',
#  '59422148.pdf',
#  '37540732.pdf',
#  '55104715.pdf',
#  '17781039.pdf',
#  '18885231.pdf',
#  '16511249.pdf',
#  '23296286.pdf',
#  '20141807.pdf',
#  '26425074.pdf',
# ...

# %%
import pandas as pd

df = pd.read_csv("Resume.csv")

print(df.shape)

df.head()

df.columns
# Out:
# (2484, 4)
# Index(['ID', 'Resume_str', 'Resume_html', 'Category'], dtype='object')

# %%
print(df.shape)

df.head()
# Out:
# (2484, 4)
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %%
df.tail()
# Out:
#             ID                                         Resume_str  \
# 2479  99416532           RANK: SGT/E-5 NON- COMMISSIONED OFFIC...
# 2480  24589765           GOVERNMENT RELATIONS, COMMUNICATIONS ...
# 2481  31605080           GEEK SQUAD AGENT         Professional...
# 2482  21190805           PROGRAM DIRECTOR / OFFICE MANAGER    ...
# 2483  37473139           STOREKEEPER II       Professional Sum...
#
#                                             Resume_html  Category
# 2479  <div class="fontsize fontface vmargins hmargin...  AVIATION
# 2480  <div class="fontsize fontface vmargins hmargin...  AVIATION
# 2481  <div class="fontsize fontface vmargins hmargin...  AVIATION
# 2482  <div class="fontsize fontface vmargins hmargin...  AVIATION
# 2483  <div class="fontsize fontface vmargins hmargin...  AVIATION

# %%
df.isnull().sum()
# Out:
# ID             0
# Resume_str     0
# Resume_html    0
# Category       0
# dtype: int64

# %%
print(
    "Number of Categories:",
    df["Category"].nunique())

df["Category"].value_counts()
# Out:
# Number of Categories: 24
# Category
# INFORMATION-TECHNOLOGY    120
# BUSINESS-DEVELOPMENT      120
# ADVOCATE                  118
# CHEF                      118
# ENGINEERING               118
# ACCOUNTANT                118
# FINANCE                   118
# FITNESS                   117
# AVIATION                  117
# SALES                     116
# BANKING                   115
# HEALTHCARE                115
# CONSULTANT                115
# CONSTRUCTION              112
# PUBLIC-RELATIONS          111
# HR                        110
# DESIGNER                  107
# ARTS                      103
# TEACHER                   102
# APPAREL                    97
# DIGITAL-MEDIA              96
# AGRICULTURE                63
# AUTOMOBILE                 36
# BPO                        22
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))

sns.countplot(
    y=df["Category"],
    order=df["Category"].value_counts().index)

plt.title("Resume Categories Distribution")

plt.show()

# %%
df["resume_length"] = df["Resume_str"].apply(len)

df["resume_length"].describe()
# Out:
# count     2484.000000
# mean      6295.308776
# std       2769.251458
# min         21.000000
# 25%       5160.000000
# 50%       5886.500000
# 75%       7227.250000
# max      38842.000000
# Name: resume_length, dtype: float64

# %%
import re

def clean_resume(text):

    text = str(text)

    text = re.sub(r"http\S+", " ", text)
    text = re.sub(r"@\S+", " ", text)
    text = re.sub(r"#\S+", " ", text)
    text = re.sub(r"[^a-zA-Z ]", " ", text)

    text = text.lower()

    return text

# %%
df["clean_resume"] = df["Resume_str"].apply( clean_resume)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer( max_features=5000, stop_words="english")

X = vectorizer.fit_transform( df["clean_resume"])

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

y = encoder.fit_transform(df["Category"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y)

# %%
df["Category"].value_counts().head(10)
# Out:
# Category
# INFORMATION-TECHNOLOGY    120
# BUSINESS-DEVELOPMENT      120
# ADVOCATE                  118
# CHEF                      118
# ENGINEERING               118
# ACCOUNTANT                118
# FINANCE                   118
# FITNESS                   117
# AVIATION                  117
# SALES                     116
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (2484, 6)

# %%
df["Category"].nunique()
# Out:
# 24

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train,y_train)

lr_pred = lr_model.predict( X_test)

# %%
from sklearn.metrics import (accuracy_score,classification_report)

print("Accuracy:",accuracy_score(y_test,lr_pred ))

print(classification_report(y_test,lr_pred))
# Out:
# Accuracy: 0.6539235412474849
#               precision    recall  f1-score   support
#
#            0       0.67      0.83      0.74        24
#            1       0.38      0.54      0.45        24
#            2       1.00      0.46      0.63        13
#            3       0.67      0.21      0.32        19
#            4       0.43      0.29      0.34        21
#            5       0.00      0.00      0.00         7
#            6       0.86      0.75      0.80        24
#            7       0.79      0.65      0.71        23
#            8       0.00      0.00      0.00         4
#            9       0.46      0.79      0.58        24
#           10       0.81      0.71      0.76        24
#           11       0.82      0.82      0.82        22
#           12       0.44      0.17      0.25        23
#           13       0.84      0.76      0.80        21
#           14       0.71      0.53      0.61        19
#           15       0.72      0.75      0.73        24
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Resume_str', 'Resume_html', 'Category', 'resume_length',
#        'clean_resume'],
#       dtype='object')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_features=10000,
    stop_words="english",
    ngram_range=(1,2))

X = vectorizer.fit_transform(
    df["clean_resume"])

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression( max_iter=3000, C=5)

# %%
df[["Resume_str","clean_resume"]].head(3)
# Out:
#                                           Resume_str  \
# 0           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1           HR SPECIALIST, US HR OPERATIONS      ...
# 2           HR DIRECTOR       Summary      Over 2...
#
#                                         clean_resume
# 0           hr administrator marketing associate ...
# 1           hr specialist  us hr operations      ...
# 2           hr director       summary      over  ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    n_jobs=-1)

rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)

print(
    "Accuracy:",
    accuracy_score(y_test, rf_pred))
# Out:
# Accuracy: 0.7082494969818913

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

nb_model = MultinomialNB()

nb_model.fit(
    X_train,
    y_train)

nb_pred = nb_model.predict(
    X_test)

print(
    "Accuracy:",
    accuracy_score(
        y_test,
        nb_pred))
# Out:
# Accuracy: 0.5513078470824949

# %%
print(df["Resume_str"].iloc[0][:1000])

print("="*50)

print(df["Resume_html"].iloc[0][:1000])
# Out:
#          HR ADMINISTRATOR/MARKETING ASSOCIATE
#
# ...

# %%
from bs4 import BeautifulSoup

def html_to_text(html):

    soup = BeautifulSoup(
        html,
        "html.parser")

    return soup.get_text(separator=" " )

# %%
df["html_text"] = df["Resume_html"].apply(
    html_to_text)

# %%
df["clean_html_resume"] = df["html_text"].apply(
    clean_resume)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_features=15000,
    stop_words="english",
    ngram_range=(1,2),
    min_df=2)

X = vectorizer.fit_transform(
    df["clean_html_resume"])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

encoder = LabelEncoder()

y = encoder.fit_transform(
    df["Category"])

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    n_jobs=-1)

rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, rf_pred))

print(classification_report(y_test, rf_pred))
# Out:
# Accuracy: 0.7424547283702213
#               precision    recall  f1-score   support
#
#            0       0.64      0.96      0.77        24
#            1       0.82      0.75      0.78        24
#            2       0.80      0.31      0.44        13
#            3       0.86      0.32      0.46        19
#            4       0.60      0.14      0.23        21
#            5       1.00      0.14      0.25         7
#            6       0.80      0.83      0.82        24
#            7       0.79      0.65      0.71        23
#            8       0.00      0.00      0.00         4
#            9       0.73      0.92      0.81        24
#           10       0.83      0.79      0.81        24
#           11       0.91      0.91      0.91        22
#           12       0.79      0.65      0.71        23
#           13       0.81      1.00      0.89        21
#           14       0.85      0.58      0.69        19
#           15       0.84      0.88      0.86        24
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

lr_model = LogisticRegression(
    max_iter=3000,
    C=5)

lr_model.fit(
    X_train,
    y_train)

lr_pred = lr_model.predict(
    X_test)

print(
    "Accuracy:",
    accuracy_score(
        y_test,
        lr_pred))

print(
    classification_report(
        y_test,
        lr_pred))
# Out:
# Accuracy: 0.6881287726358148
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.75        24
#            1       0.50      0.71      0.59        24
#            2       1.00      0.54      0.70        13
#            3       0.50      0.26      0.34        19
#            4       0.53      0.43      0.47        21
#            5       1.00      0.29      0.44         7
#            6       0.81      0.71      0.76        24
#            7       0.76      0.70      0.73        23
#            8       0.00      0.00      0.00         4
#            9       0.61      0.92      0.73        24
#           10       0.86      0.75      0.80        24
#           11       0.77      0.77      0.77        22
#           12       0.62      0.35      0.44        23
#           13       0.84      0.76      0.80        21
#           14       0.69      0.47      0.56        19
#           15       0.72      0.75      0.73        24
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

nb_model = MultinomialNB()

nb_model.fit(
    X_train,
    y_train)

nb_pred = nb_model.predict(
    X_test)

print(
    "Accuracy:",
    accuracy_score(
        y_test,
        nb_pred))

print(
    classification_report(
        y_test,
        nb_pred))
# Out:
# Accuracy: 0.5533199195171026
#               precision    recall  f1-score   support
#
#            0       0.49      0.88      0.63        24
#            1       0.30      0.38      0.33        24
#            2       1.00      0.08      0.14        13
#            3       0.50      0.05      0.10        19
#            4       0.75      0.14      0.24        21
#            5       0.00      0.00      0.00         7
#            6       0.82      0.58      0.68        24
#            7       0.87      0.57      0.68        23
#            8       0.00      0.00      0.00         4
#            9       0.38      0.88      0.53        24
#           10       0.82      0.75      0.78        24
#           11       0.62      0.68      0.65        22
#           12       1.00      0.04      0.08        23
#           13       0.76      0.62      0.68        21
#           14       0.67      0.21      0.32        19
#           15       0.70      0.58      0.64        24
# ...

# %% [markdown]
# ## Final Results
#
# Three machine learning models were evaluated for resume classification using text extracted from Resume_html and transformed using TF-IDF vectorization.
#
# The performance of the models was as follows:
#
# * Random Forest: 74.2%
# * Logistic Regression: 68.0%
# * Naive Bayes: 55.0%
#
# Random Forest achieved the highest classification accuracy and demonstrated superior ability to distinguish between 24 different job categories.
#
# Additionally, using text extracted from the Resume_html field improved performance compared to using the Resume_str field, suggesting that the HTML structure preserved valuable contextual information.
#
# Therefore, Random Forest trained on cleaned Resume_html text was selected as the final model for resume classification.
